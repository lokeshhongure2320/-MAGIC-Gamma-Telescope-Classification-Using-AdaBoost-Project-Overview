# %% [markdown]
# # Project Title:  MAGIC Gamma Telescope
# ---
# ## Problem statement : The objective is to develop a classification model to distinguish between high-energy gamma-ray signals and background hadrons using data from the MAGIC Gamma Telescope.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MAGIC Gamma Telescope.csv')

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 0       -8.2027  40.0920   81.8828     g
# 1       -9.9574   6.3609  205.2610     g
# ...

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df.shape
# Out:
# (19020, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   19020 non-null  float64
#  1   fWidth    19020 non-null  float64
#  2   fSize     19020 non-null  float64
#  3   fConc     19020 non-null  float64
#  4   fConc1    19020 non-null  float64
#  5   fAsym     19020 non-null  float64
#  6   fM3Long   19020 non-null  float64
#  7   fM3Trans  19020 non-null  float64
#  8   fAlpha    19020 non-null  float64
#  9   fDist     19020 non-null  float64
#  10  class     19020 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# ...

# %% [markdown]
# ## Null Values

# %%
df.isna().sum()
# Out:
# fLength     0
# fWidth      0
# fSize       0
# fConc       0
# fConc1      0
# fAsym       0
# fM3Long     0
# fM3Trans    0
# fAlpha      0
# fDist       0
# class       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 115

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df:
    print(df[i].value_counts())
    print('*'*100)
# Out:
# fLength
# 19.1572     3
# 24.8332     3
# 26.9187     3
# 31.3405     2
# 12.9833     2
#            ..
# 29.4859     1
# 24.2378     1
# 20.4820     1
# 31.2490     1
# 187.1814    1
# Name: count, Length: 18643, dtype: int64
# ****************************************************************************************************
# fWidth
# 0.0000     98
# 10.7539     4
# 15.8644     3
# 0.0028      3
# 15.0295     3
#            ..
# 7.0834      1
# 14.8631     1
# 18.8241     1
# 15.5129     1
# 53.0014     1
# Name: count, Length: 18200, dtype: int64
# ****************************************************************************************************
# fSize
# 2.1508    27
# 2.0774    24
# 2.1287    24
# 2.1319    23
# 2.3139    22
#           ..
# 3.5619     1
# 3.5105     1
# 3.9986     1
# 3.1555     1
# 3.2093     1
# Name: count, Length: 7228, dtype: int64
# ****************************************************************************************************
# fConc
# ...

# %%
num_col = df.select_dtypes(exclude = 'object')
n = num_col

# %%
n.columns
# Out:
# Index(['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long',
#        'fM3Trans', 'fAlpha', 'fDist'],
#       dtype='object')

# %% [markdown]
# ##    Outliers

# %%
for i in n:
    plt.boxplot(n[i])
    plt.title(i)
    plt.show()

# %%
#width
q1=df['fLength'].quantile(0.25)
q3=df['fLength'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 24.3597
# q3 69.9754
# iqr 45.61569999999999
# upper_tail 138.39894999999996
# lower_tail -44.063849999999974

# %%
df.loc[df['fLength']>ub , 'fLength']=ub

# %%
q1=df['fWidth'].quantile(0.25)
q3=df['fWidth'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 11.8742
# q3 24.7124
# iqr 12.838199999999999
# upper_tail 43.969699999999996
# lower_tail -7.383099999999997

# %%
df.loc[df['fWidth']>ub , 'fWidth']=ub

# %%
q1=df['fSize'].quantile(0.25)
q3=df['fSize'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 2.4771
# q3 3.1011
# iqr 0.6240000000000001
# upper_tail 4.037100000000001
# lower_tail 1.5411

# %%
df.loc[df['fSize']>ub , 'fSize']=ub

# %%
q1=df['fConc1'].quantile(0.25)
q3=df['fConc1'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 0.1285
# q3 0.285
# iqr 0.15649999999999997
# upper_tail 0.5197499999999999
# lower_tail -0.10624999999999996

# %%
df.loc[df['fConc1']>ub , 'fConc1']=ub

# %%
q1=df['fAsym'].quantile(0.25)
q3=df['fAsym'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 -20.4791
# q3 24.1335
# iqr 44.6126
# upper_tail 91.0524
# lower_tail -87.39800000000001

# %%
df.loc[df['fAsym']>ub , 'fAsym']=ub
df.loc[df['fAsym']<lb , 'fAsym']=lb

# %%
q1=df['fM3Long'].quantile(0.25)
q3=df['fM3Long'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 -12.7693
# q3 35.8694
# iqr 48.6387
# upper_tail 108.82745
# lower_tail -85.72735

# %%
df.loc[df['fM3Long']>ub , 'fM3Long']=ub
df.loc[df['fM3Long']<lb , 'fM3Long']=lb

# %%
q1=df['fM3Trans'].quantile(0.25)
q3=df['fM3Trans'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 -10.8358
# q3 10.9489
# iqr 21.7847
# upper_tail 43.62595
# lower_tail -43.51285

# %%
df.loc[df['fM3Trans']>ub , 'fM3Trans']=ub
df.loc[df['fM3Trans']<lb , 'fM3Trans']=lb

# %%
q1=df['fDist'].quantile(0.25)
q3=df['fDist'].quantile(0.75)
iqr=q3-q1
ub=q3+(1.5*iqr)
lb=q1-(1.5*iqr)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("upper_tail",ub)
print("lower_tail",lb)
# Out:
# q1 142.269
# q3 240.409
# iqr 98.13999999999999
# upper_tail 387.61899999999997
# lower_tail -4.940999999999974

# %%
df.loc[df['fDist']>ub , 'fDist']=ub

# %%
for i in n:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# ## Labelencoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['class'] = le.fit_transform(df['class'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25464\3103526801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = le.fit_transform(df['class'])

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
a = MinMaxScaler()

# %%
for i in df:
    df[i]=a.fit_transform(df[[i]])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25464\3633935177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=a.fit_transform(df[[i]])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25464\3633935177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=a.fit_transform(df[[i]])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25464\3633935177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Correlation heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr().tail(1), annot=True )
plt.title("Correlation Matrix")
plt.show()

# %%
for i in df:
    sns.histplot(df[i],kde = True)
    plt.title(i)
    plt.show()

# %%
from scipy.stats import skew

# %%
for i in df:
    print(i,"===>",skew(df[i]))
# Out:
# fLength ===> 1.150012152336317
# fWidth ===> 0.9634746335811686
# fSize ===> 0.6919862477738468
# fConc ===> 0.48850120314978607
# fConc1 ===> 0.6246670394298843
# fAsym ===> -0.3765677142896164
# fM3Long ===> -0.21666498114274463
# fM3Trans ===> 0.023152140114259364
# fAlpha ===> 0.8573882349831167
# fDist ===> 0.19440010108783
# class ===> 0.6396589846451801

# %% [markdown]
# ## Train Test Split

# %%
x = df.drop('class',axis = 1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=11)

# %% [markdown]
# # Handling imbalanced data

# %%
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE(random_state=10)
smote_x_train, smote_y_train = smt.fit_resample(x_train,y_train)

# %%
from collections import Counter

# %%
Counter(y_train)
# Out:
# Counter({0.0: 9855, 1.0: 5269})

# %%
Counter(smote_y_train)
# Out:
# Counter({1.0: 9855, 0.0: 9855})

# %% [markdown]
# ## Model Traning

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation

# %%
# testing Accuracy
y_pred = model.predict(x_test)

cnf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cnf_matrix)
print("*"*45)

# visualization also

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print("*"*45)

clf_report = classification_report(y_test, y_pred)
print("Classification Report:\n",clf_report)
# Out:
# Confusion Matrix:
#  [[2251  226]
#  [ 561  743]]
# *********************************************
# Accuracy:  0.7918540068764877
# *********************************************
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.91      0.85      2477
#          1.0       0.77      0.57      0.65      1304
#
#     accuracy                           0.79      3781
#    macro avg       0.78      0.74      0.75      3781
# weighted avg       0.79      0.79      0.78      3781

# %%
# Training Accuracy
y_pred_train = model.predict(x_train)

cnf_matrix = confusion_matrix(y_train, y_pred_train)
print("Confusion Matrix:\n", cnf_matrix)
print("*"*45)

accuracy = accuracy_score(y_train, y_pred_train)
print("Accuracy: ",accuracy)
print("*"*45)

clf_report = classification_report(y_train, y_pred_train)
print("Classification Report:\n",clf_report)
# Out:
# Confusion Matrix:
#  [[8875  980]
#  [2124 3145]]
# *********************************************
# Accuracy:  0.794763290134885
# *********************************************
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.90      0.85      9855
#          1.0       0.76      0.60      0.67      5269
#
#     accuracy                           0.79     15124
#    macro avg       0.78      0.75      0.76     15124
# weighted avg       0.79      0.79      0.79     15124

# %% [markdown]
# ## Model Traning

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_model = AdaBoostClassifier(random_state=11)
ada_model.fit(x_train, y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(random_state=11)

# %% [markdown]
# ## Model Evaluation

# %%
# testing Accuracy
y_pred = ada_model.predict(x_test)

cnf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cnf_matrix)
print("*"*45)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print("*"*45)

clf_report = classification_report(y_test, y_pred)
print("Classification Report:\n",clf_report)
# Out:
# Confusion Matrix:
#  [[2257  220]
#  [ 391  913]]
# *********************************************
# Accuracy:  0.8384025390108437
# *********************************************
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88      2477
#          1.0       0.81      0.70      0.75      1304
#
#     accuracy                           0.84      3781
#    macro avg       0.83      0.81      0.82      3781
# weighted avg       0.84      0.84      0.84      3781

# %%
# Training Accuracy
y_pred_train = ada_model.predict(x_train)

cnf_matrix = confusion_matrix(y_train, y_pred_train)
print("Confusion Matrix:\n", cnf_matrix)
print("*"*45)

accuracy = accuracy_score(y_train, y_pred_train)
print("Accuracy: ",accuracy)
print("*"*45)

clf_report = classification_report(y_train, y_pred_train)
print("Classification Report:\n",clf_report)
# Out:
# Confusion Matrix:
#  [[9062  793]
#  [1464 3805]]
# *********************************************
# Accuracy:  0.850766992859032
# *********************************************
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.92      0.89      9855
#          1.0       0.83      0.72      0.77      5269
#
#     accuracy                           0.85     15124
#    macro avg       0.84      0.82      0.83     15124
# weighted avg       0.85      0.85      0.85     15124
